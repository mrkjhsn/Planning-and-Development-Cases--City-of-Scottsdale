# %% [markdown]
# ### The City of Scottsdale publishes a [dataset](http://data.scottsdaleaz.gov/dataset/planning-and-development-cases) that includes planning and development cases dating back to the 1970s.
#
# ### How many hearings, and which type of hearings does each case go through as part of the case hearing process?

# %%
import pyodbc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# databaseConnection = 'DRIVER={SQL Server}; SERVER=ServerName; Database=DatbaseName; UID=UserId; PWD=password;'
connection = pyodbc.connect('DRIVER={SQL Server};SERVER=WINDOWS-A6S01I2\SQLEXPRESS;DATABASE=City_of_Scottsdale;Trusted_Connection=yes;')
cursor = connection.cursor()

# query excludes observations that don't have 'meeting type', 'meeting type' is ambiguous or
# the meeting took place prior to when Scottsdale was incorporated(1951), probably human data entry error
Case_Query = '''
select *
from [dbo].[pds_CaseMeetings]
where [MeetingType] <> '' and [MeetingType] <> 'Other' and year([MeetingDate]) > '1951' 
  '''
# save the sql query to a pandas dataframe
Case_Data = pd.read_sql(Case_Query, connection)
connection.close()

Case_Data['MeetingDate'] = pd.to_datetime(Case_Data['MeetingDate']) #converte MeetingDate to datetime format
Case_Data['MeetingDate'] = Case_Data['MeetingDate'].dt.year #converte MeetingDate to year

Case_Data.head()
# Out:
#   meeting_id case_id CaseNumber                  MeetingType  MeetingDate  \
# 0       7571   20987  4-UP-2001         City Council Hearing         2001
# 1       7573   20988  5-UP-2001  Planning Commission Hearing         2001
# 2       7574   20988  5-UP-2001         City Council Hearing         2001
# 3       7575   20990  3-ZN-2001  Planning Commission Hearing         2001
# 4       7576   20990  3-ZN-2001         City Council Hearing         2001
#
#       Result  Vote
# 0   APPROVED  7-0
# 1  CONTINUED
# 2   APPROVED   7-0
# 3  CONTINUED   6-0
# 4   APPROVED   7-0

# %%
Case_Data.case_id.count()
# Out:
# 15401

# %%
# it seems both case_id and CaseNumber are unique and roughly similar
Case_Data.CaseNumber.count()
# Out:
# 15401

# %%
Case_Data.meeting_id.count()
# Out:
# 15401

# %%
Case_Data.meeting_id.value_counts().head()
# Out:
# 54667    1
# 32510    1
# 24862    1
# 5691     1
# 33691    1
# Name: meeting_id, dtype: int64

# %%
Case_Data.CaseNumber.value_counts().head(10)
# Out:
#                 1773
# 12-GP-1999        22
# 6-TA-2009#2       21
# 19-ZN-1987#2      14
# 12-GP-1994        14
# 65-ZN-1992#7      14
# 2-ZN-2000         14
# 3-TA-2000         13
# 2-II-2010         13
# 9-UP-2000         12
# Name: CaseNumber, dtype: int64

# %%
Case_Data.groupby(Case_Data.CaseNumber).get_group('9-UP-2000').sort_values(by='MeetingDate', ascending=False)
# Out:
#       meeting_id case_id CaseNumber                  MeetingType  MeetingDate  \
# 367        10866   19935  9-UP-2000         City Council Hearing         2002
# 9602       10397   19935  9-UP-2000         City Council Hearing         2002
# 10710      10488   19935  9-UP-2000         City Council Hearing         2002
# 11051      10783   19935  9-UP-2000         City Council Hearing         2002
# 8277        7540   19935  9-UP-2000         City Council Hearing         2001
# 8278        7541   19935  9-UP-2000         City Council Hearing         2001
# 9403        9476   19935  9-UP-2000         City Council Hearing         2001
# 9429        9747   19935  9-UP-2000         City Council Hearing         2001
# 9547       10213   19935  9-UP-2000         City Council Hearing         2001
# 10192       8833   19935  9-UP-2000         City Council Hearing         2001
# 8185        6152   19935  9-UP-2000  Planning Commission Hearing         2000
# 8186        6877   19935  9-UP-2000  Planning Commission Hearing         2000
#
#           Result Vote
# 367     APPROVED  7-0
# 9602   CONTINUED
# 10710  CONTINUED
# 11051  CONTINUED
# 8277
# 8278     ON HOLD
# 9403   CONTINUED
# 9429   CONTINUED
# 9547   CONTINUED  7-0
# 10192  CONTINUED
# 8185   CONTINUED
# 8186    APPROVED  7-0

# %%
Case_Data.head()
# Out:
#   meeting_id case_id CaseNumber                  MeetingType  MeetingDate  \
# 0       7571   20987  4-UP-2001         City Council Hearing         2001
# 1       7573   20988  5-UP-2001  Planning Commission Hearing         2001
# 2       7574   20988  5-UP-2001         City Council Hearing         2001
# 3       7575   20990  3-ZN-2001  Planning Commission Hearing         2001
# 4       7576   20990  3-ZN-2001         City Council Hearing         2001
#
#       Result  Vote
# 0   APPROVED  7-0
# 1  CONTINUED
# 2   APPROVED   7-0
# 3  CONTINUED   6-0
# 4   APPROVED   7-0

# %%
Case_Data.groupby([Case_Data.case_id, Case_Data.MeetingType]).size().reset_index().sort_values(by=[0, "case_id"], ascending=False)
# Out:
#       case_id                      MeetingType   0
# 13282     757             City Council Hearing  11
# 5076     2696             City Council Hearing  11
# 2393     1865             City Council Hearing  11
# 2394     1865      Planning Commission Hearing  11
# 4756    25973       Development Review Hearing  10
# 2807    19935             City Council Hearing  10
# 12288     562             City Council Hearing   9
# 8232    38117      Planning Commission Hearing   9
# 2906    20351       Development Review Hearing   9
# 9352    41582       Development Review Hearing   8
# 8755    39591       Development Review Hearing   8
# 2682    19690       Development Review Hearing   8
# 2106    18272       Development Review Hearing   8
# 1906    18077       Development Review Hearing   8
# 1852    18022       Development Review Hearing   8
# 1620    17787       Development Review Hearing   8
# 1619    17786       Development Review Hearing   8
# 13046    7106             City Council Hearing   7
# 13047    7106      Planning Commission Hearing   7
# 6208    30895      Planning Commission Hearing   7
# 2973    20669             City Council Hearing   7
# 1717    17888       Development Review Hearing   7
# 617     17067             City Council Hearing   7
# 618     17067      Planning Commission Hearing   7
# 11941   48900  Historic Preservation Committee   6
# 9576    42240       Development Review Hearing   6
# 8395    38537             City Council Hearing   6
# 7583    36133      Planning Commission Hearing   6
# 5438    28012      Planning Commission Hearing   6
# 3495    22179             City Council Hearing   6
# ...       ...                              ...  ..
# 28      10262             City Council Hearing   1
# 29      10262      Planning Commission Hearing   1
# 26      10261             City Council Hearing   1
# 27      10261      Planning Commission Hearing   1
# 24      10260             City Council Hearing   1
# 25      10260      Planning Commission Hearing   1
# 22      10259             City Council Hearing   1
# 23      10259      Planning Commission Hearing   1
# 20      10258             City Council Hearing   1
# 21      10258      Planning Commission Hearing   1
# 18      10257             City Council Hearing   1
# 19      10257      Planning Commission Hearing   1
# 16      10256             City Council Hearing   1
# 17      10256      Planning Commission Hearing   1
# 14      10255             City Council Hearing   1
# 15      10255      Planning Commission Hearing   1
# 12      10251             City Council Hearing   1
# 13      10251      Planning Commission Hearing   1
# 10      10250             City Council Hearing   1
# 11      10250      Planning Commission Hearing   1
# 9        1025       Development Review Hearing   1
# 7       10249             City Council Hearing   1
# 8       10249      Planning Commission Hearing   1
# 5       10248             City Council Hearing   1
# 6       10248      Planning Commission Hearing   1
# 4        1024       Development Review Hearing   1
# 3       10239      Planning Commission Hearing   1
# 2        1022       Development Review Hearing   1
# 1        1014       Development Review Hearing   1
# 0        1008       Development Review Hearing   1
#
# [13403 rows x 3 columns]
